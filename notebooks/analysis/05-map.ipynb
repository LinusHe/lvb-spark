# %%
# Import necessary libraries and initialize SparkSession
from pyspark.sql.functions import explode, col, broadcast, avg, lit, count
from pyspark.sql import functions as F
from pyspark.sql.types import StructType, StructField, StringType
from pyspark.sql.functions import rand
from IPython.display import display, HTML
import pandas as pd
import matplotlib.pyplot as plt
import time
import json
import folium

# %run "/usr/local/spark/notebooks/00-spark-connection.ipynb"

# Set shuffle partitions to match the number of cores for better performance
spark.conf.set("spark.sql.shuffle.partitions", "8")  # Adjust as needed

# %%
def load_parquet_data(file_path):
    start_time = time.time()
    df = spark.read.parquet(file_path)
    print(f"Loaded Parquet data in {time.time() - start_time:.2f} seconds")
    return df

def load_json_data(file_path):
    start_time = time.time()
    with open(file_path, "r") as file:
        json_data = json.load(file)
    print(f"Loaded JSON data in {time.time() - start_time:.2f} seconds")
    return json_data

def create_dataframe_from_json(json_data, schema, row_mapper):
    rows = row_mapper(json_data)
    df = spark.createDataFrame(rows, schema)
    # df.show(5)
    return df

def join_dataframes(df1, df2, join_condition, select_columns):
    start_time = time.time()
    joined_df = df1.join(df2, join_condition, "left").select(*select_columns)
    # joined_df.show(5)
    print(f"Joined data in {time.time() - start_time:.2f} seconds")
    return joined_df

# Load enriched departures from Parquet file
df = load_parquet_data("data/enriched_01.parquet")

# Load line data
line_json_data = load_json_data("data/relevantLines_with_stops.json")

# Define the schema for the line DataFrame
line_schema = StructType([
    StructField("line_id", StringType(), True),
    StructField("name", StringType(), True),
    StructField("product", StringType(), True)
])

# Create the line DataFrame
lines_df = create_dataframe_from_json(line_json_data, line_schema, lambda data: [(line_id, line_info['name'], line_info['product']) for line_id, line_info in data.items()])

# Cache the lines_df as it will be reused
lines_df.cache()

# Join the enriched departures with the line information
joined_df = join_dataframes(df, lines_df, df.lineId == lines_df.line_id, [df["*"], lines_df.name.alias("line_name"), lines_df.product.alias("line_product")])

# Load stops data
stops_json_data = load_json_data("data/stops.json")

# Define the schema for the stops DataFrame
stops_schema = StructType([
    StructField("stop_id", StringType(), True),
    StructField("stop_name", StringType(), True),
    StructField("latitude", StringType(), True),
    StructField("longitude", StringType(), True)
])

# Create the stops DataFrame
stops_df = create_dataframe_from_json(stops_json_data['stops'], stops_schema, lambda data: [(stop['id'], stop['name'], stop['latitude'], stop['longitude']) for stop in data])

# Cache the stops_df as it will be reused
stops_df.cache()

# Join the enriched departures with the line and stop information
final_df = join_dataframes(joined_df, stops_df, joined_df.stopId == stops_df.stop_id, [joined_df["*"], stops_df.stop_name.alias("stop_name"), stops_df.latitude.alias("stop_latitude"), stops_df.longitude.alias("stop_longitude")])
# Out:
# Loaded Parquet data in 26.17 seconds
# Loaded JSON data in 0.01 seconds
# Joined data in 0.43 seconds
# Loaded JSON data in 0.28 seconds
# Joined data in 0.90 seconds

# %%
# Get a random tripId with at least 3 different added delay values
valid_trips = final_df.groupBy("tripId").agg(F.countDistinct("added_delay").alias("distinct_delays")) \
                      .filter(col("distinct_delays") >= 3) \
                      .select("tripId") \
                      .distinct() \
                      .orderBy(rand()) \
                      .limit(1) \
                      .collect()

# Get a random tripId
random_trip = valid_trips[0]["tripId"]

# Filter the dataframe for the selected trip and order by plannedWhen
trip_stops = final_df.filter(col("tripId") == random_trip) \
                     .select("stop_name", "stop_latitude", "stop_longitude", "plannedWhen", "when", "delay", "added_delay", "line_name", "line_product", "direction") \
                     .orderBy("plannedWhen")

# Collect the stop data
stops_data = trip_stops.collect()

if stops_data:
    start_stop = stops_data[0]
    end_stop = stops_data[-1]
    avg_delay = sum([float(stop["delay"]) for stop in stops_data]) / len(stops_data)
    
    # Calculate duration between start and stop
    start_time = pd.to_datetime(start_stop["plannedWhen"])
    end_time = pd.to_datetime(end_stop["plannedWhen"])
    duration = (end_time - start_time).total_seconds() / 60  # duration in minutes
    
    # Create a table with the specified columns
    stops_table_data = {
        "Stop Name": [stop["stop_name"] for stop in stops_data],
        "Planned When": [stop["plannedWhen"] for stop in stops_data],
        "When": [stop["when"] for stop in stops_data],
        "Delay": [stop["delay"] for stop in stops_data],
        "Added Delay": [stop["added_delay"] for stop in stops_data]
    }
    stops_table_df = pd.DataFrame(stops_table_data)
    
    # Create a table for the additional information
    additional_info_data = {
        "Info": ["Trip ID", "Line Name", "Direction", "Line Product", "Start Stop", "Start Planned When", "Start Actual When", "End Stop", "End Planned When", "End Actual When", "Average Delay", "Start Delay", "End Delay", "Duration"],
        "Value": [random_trip, start_stop['line_name'], start_stop['direction'], start_stop['line_product'], start_stop['stop_name'], start_stop['plannedWhen'], start_stop['when'], end_stop['stop_name'], end_stop['plannedWhen'], end_stop['when'], f"{avg_delay:.2f} minutes", f"{start_stop['delay']} seconds", f"{end_stop['delay']} seconds", f"{duration:.2f} minutes"]
    }
    additional_info_df = pd.DataFrame(additional_info_data)
    
    # Display the tables side by side
    display_html = f"""
    <div style="display: flex; justify-content: space-around;">
        <div>{additional_info_df.to_html(index=False)}</div>
        <div>{stops_table_df.to_html(index=False)}</div>
    </div>
    """
    display(HTML(display_html))
    
    avg_latitude = sum([float(stop["stop_latitude"]) for stop in stops_data]) / len(stops_data)
    avg_longitude = sum([float(stop["stop_longitude"]) for stop in stops_data]) / len(stops_data)
    m = folium.Map(location=[avg_latitude, avg_longitude], zoom_start=13)

    # Create a feature group for the stops
    stops_group = folium.FeatureGroup(name='Stops')

    # Function to map delay to a color for stops
    def stop_delay_to_color(delay):
        if delay < 0:
            return 'blue'
        elif delay <= 0:
            return 'green'
        elif delay <= 60:
            return 'lightred'
        elif delay <= 120:
            return 'orange'
        else:
            return 'red'

    # Add a marker for each stop with different icons for start, end, and intermediate stops
    for i, stop in enumerate(stops_data):
        stop_color = stop_delay_to_color(float(stop["delay"]))
        if i == 0:
            # Start stop
            folium.Marker(
                location=[float(stop["stop_latitude"]), float(stop["stop_longitude"])],
                popup=f"{stop['stop_name']} ({stop['plannedWhen']})",
                icon=folium.Icon(color=stop_color, icon='play', prefix='fa')
            ).add_to(stops_group)
        elif i == len(stops_data) - 1:
            # End stop
            folium.Marker(
                location=[float(stop["stop_latitude"]), float(stop["stop_longitude"])],
                popup=f"{stop['stop_name']} ({stop['plannedWhen']})",
                icon=folium.Icon(color=stop_color, icon='stop', prefix='fa')
            ).add_to(stops_group)
        else:
            # Intermediate stops
            folium.Marker(
                location=[float(stop["stop_latitude"]), float(stop["stop_longitude"])],
                popup=f"{stop['stop_name']} ({stop['plannedWhen']})",
                icon=folium.Icon(color=stop_color, icon='circle', prefix='fa')
            ).add_to(stops_group)

    # Add the stops group to the map
    stops_group.add_to(m)

    # Create a list of coordinates for the stops
    coords = [[float(stop["stop_latitude"]), float(stop["stop_longitude"])] for stop in stops_data]
    colors = [float(stop["added_delay"]) for stop in stops_data[1:]]  # Colors based on added delay for each segment

    # Normalize colors to be between 0 and 1 for colormap, with 300 seconds as the maximum delay
    max_delay = 300
    colors = [min(delay / max_delay, 1) for delay in colors]

    # Add a ColorLine to the map
    folium.ColorLine(
        positions=coords,
        colors=colors,
        colormap=["green", "yellow", "orange", "red"],
        weight=5
    ).add_to(m)

    # Display the map
    display(m)
else:
    print("No stops found for the selected trip.")
# Out:
#     <div style="display: flex; justify-content: space-around;">
#         <div><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Info</th>
#       <th>Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>Trip ID</td>
#       <td>1|301316|1|81|24122023</td>
#     </tr>
#     <tr>
#       <td>Line Name</td>
#       <td>Bus 70</td>
#     </tr>
#     <tr>
#       <td>Direction</td>
#       <td>Thekla</td>
#     </tr>
#     <tr>
#       <td>Line Product</td>
#       <td>bus</td>
#     </tr>
#     <tr>
#       <td>Start Stop</td>
#       <td>Markkleeberg West</td>
#     </tr>
#     <tr>
#       <td>Start Planned When</td>
#       <td>2023-12-24 05:55:00</td>
#     </tr>
#     <tr>
#       <td>Start Actual When</td>
#       <td>2023-12-24 05:58:00</td>
#     </tr>
#     <tr>
#       <td>End Stop</td>
#       <td>Neutzscher Str., Leipzig</td>
#     </tr>
#     <tr>
#       <td>End Planned When</td>
#       <td>2023-12-24 06:47:00</td>
#     </tr>
#     <tr>
#       <td>End Actual When</td>
#       <td>2023-12-24 06:49:00</td>
#     </tr>
#     <tr>
#       <td>Average Delay</td>
#       <td>110.77 minutes</td>
#     </tr>
#     <tr>
#       <td>Start Delay</td>
#       <td>180 seconds</td>
#     </tr>
#     <tr>
#       <td>End Delay</td>
#       <td>120 seconds</td>
#     </tr>
#     <tr>
#       <td>Duration</td>
#       <td>52.00 minutes</td>
#     </tr>
#   </tbody>
# </table></div>
#         <div><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Stop Name</th>
#       <th>Planned When</th>
#       <th>When</th>
#       <th>Delay</th>
#       <th>Added Delay</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>Markkleeberg West</td>
#       <td>2023-12-24 05:55:00</td>
#       <td>2023-12-24 05:58:00</td>
#       <td>180</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>Ring, Markkleeberg</td>
#       <td>2023-12-24 05:56:00</td>
#       <td>2023-12-24 05:59:00</td>
#       <td>180</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>S-Bahnhof (Bus), Markkleeberg</td>
#       <td>2023-12-24 05:57:00</td>
#       <td>2023-12-24 06:00:00</td>
#       <td>180</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>Parkstr., Markkleeberg</td>
#       <td>2023-12-24 05:58:00</td>
#       <td>2023-12-24 06:01:00</td>
#       <td>180</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>Forsthaus Raschwitz, Markkleeberg</td>
#       <td>2023-12-24 06:00:00</td>
#       <td>2023-12-24 06:03:00</td>
#       <td>180</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>Wildpark, Leipzig</td>
#       <td>2023-12-24 06:01:00</td>
#       <td>2023-12-24 06:04:00</td>
#       <td>180</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>Koburger Brücke, Leipzig</td>
#       <td>2023-12-24 06:02:00</td>
#       <td>2023-12-24 06:05:00</td>
#       <td>180</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>Leopoldstr., Leipzig</td>
#       <td>2023-12-24 06:03:00</td>
#       <td>2023-12-24 06:06:00</td>
#       <td>180</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>Mathildenstr., Leipzig</td>
#       <td>2023-12-24 06:04:00</td>
#       <td>2023-12-24 06:04:00</td>
#       <td>0</td>
#       <td>-180</td>
#     </tr>
#     <tr>
#       <td>Connewitzer Kreuz, Leipzig</td>
#       <td>2023-12-24 06:10:00</td>
#       <td>2023-12-24 06:10:00</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>Richard-Lehmann-Str./HTWK, Leipzig</td>
#       <td>2023-12-24 06:11:00</td>
#       <td>2023-12-24 06:11:00</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>Arthur-Hoffmann-/Richard-Lehmann-Str., Leipzig</td>
#       <td>2023-12-24 06:12:00</td>
#       <td>2023-12-24 06:12:00</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>Altenburger Str., Leipzig</td>
#       <td>2023-12-24 06:14:00</td>
#       <td>2023-12-24 06:14:00</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>Richard-Lehmann-/Zwickauer Str., Leipzig</td>
#       <td>2023-12-24 06:15:00</td>
#       <td>2023-12-24 06:15:00</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>An der Tabaksmühle, Leipzig</td>
#       <td>2023-12-24 06:17:00</td>
#       <td>2023-12-24 06:17:00</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>Naunhofer Str., Leipzig</td>
#       <td>2023-12-24 06:18:00</td>
#       <td>2023-12-24 06:20:00</td>
#       <td>120</td>
#       <td>120</td>
#     </tr>
#     <tr>
#       <td>Altes Messegelände, Leipzig</td>
#       <td>2023-12-24 06:20:00</td>
#       <td>2023-12-24 06:22:00</td>
#       <td>120</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>Technisches Rathaus, Leipzig</td>
#       <td>2023-12-24 06:21:00</td>
#       <td>2023-12-24 06:23:00</td>
#       <td>120</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>Riebeck-/Stötteritzer Str., Leipzig</td>
#       <td>2023-12-24 06:22:00</td>
#       <td>2023-12-24 06:24:00</td>
#       <td>120</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>Riebeck-/Oststr., Leipzig</td>
#       <td>2023-12-24 06:23:00</td>
#       <td>2023-12-24 06:25:00</td>
#       <td>120</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>Breite Str., Leipzig</td>
#       <td>2023-12-24 06:25:00</td>
#       <td>2023-12-24 06:27:00</td>
#       <td>120</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>Reudnitz Koehlerstr., Leipzig</td>
#       <td>2023-12-24 06:27:00</td>
#       <td>2023-12-24 06:29:00</td>
#       <td>120</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>Bergstr., Leipzig</td>
#       <td>2023-12-24 06:28:00</td>
#       <td>2023-12-24 06:30:00</td>
#       <td>120</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>Dornbergerstr., Leipzig</td>
#       <td>2023-12-24 06:30:00</td>
#       <td>2023-12-24 06:32:00</td>
#       <td>120</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>Hermann-Liebmann-/Eisenbahnstr., Leipzig</td>
#       <td>2023-12-24 06:31:00</td>
#       <td>2023-12-24 06:33:00</td>
#       <td>120</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>Stannebeinplatz, Leipzig</td>
#       <td>2023-12-24 06:33:00</td>
#       <td>2023-12-24 06:35:00</td>
#       <td>120</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>Stöckelstr., Leipzig</td>
#       <td>2023-12-24 06:34:00</td>
#       <td>2023-12-24 06:36:00</td>
#       <td>120</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>Löbauer Str., Leipzig</td>
#       <td>2023-12-24 06:35:00</td>
#       <td>2023-12-24 06:37:00</td>
#       <td>120</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>Julian-Marchlewski-Str., Leipzig</td>
#       <td>2023-12-24 06:37:00</td>
#       <td>2023-12-24 06:39:00</td>
#       <td>120</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>Bertolt-Brecht-Str., Leipzig</td>
#       <td>2023-12-24 06:38:00</td>
#       <td>2023-12-24 06:40:00</td>
#       <td>120</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>Schönefeld Ost (Verbundnetz Gas AG), Leipzig</td>
#       <td>2023-12-24 06:39:00</td>
#       <td>2023-12-24 06:41:00</td>
#       <td>120</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>Braun-/Bautzner Str., Leipzig</td>
#       <td>2023-12-24 06:39:00</td>
#       <td>2023-12-24 06:41:00</td>
#       <td>120</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>Stöhrer-/Braunstr., Leipzig</td>
#       <td>2023-12-24 06:40:00</td>
#       <td>2023-12-24 06:42:00</td>
#       <td>120</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>Abtnaundorf, Leipzig</td>
#       <td>2023-12-24 06:41:00</td>
#       <td>2023-12-24 06:43:00</td>
#       <td>120</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>Heiterblickstr., Leipzig</td>
#       <td>2023-12-24 06:42:00</td>
#       <td>2023-12-24 06:44:00</td>
#       <td>120</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>S-Bahnhof Thekla (Bus), Leipzig</td>
#       <td>2023-12-24 06:43:00</td>
#       <td>2023-12-24 06:45:00</td>
#       <td>120</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>Freiberger Str., Leipzig</td>
#       <td>2023-12-24 06:44:00</td>
#       <td>2023-12-24 06:46:00</td>
#       <td>120</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>Sosaer Str., Leipzig</td>
#       <td>2023-12-24 06:45:00</td>
#       <td>2023-12-24 06:47:00</td>
#       <td>120</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>Neutzscher Str., Leipzig</td>
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f81ae736cc53623d3e8882c948d53abd {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f81ae736cc53623d3e8882c948d53abd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f81ae736cc53623d3e8882c948d53abd = L.map(
#                 &quot;map_f81ae736cc53623d3e8882c948d53abd&quot;,
#                 {
#                     center: [51.33165374358975, 12.401294153846154],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b1c567519f8f0e53839dfe3014c33eea = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_b1c567519f8f0e53839dfe3014c33eea.addTo(map_f81ae736cc53623d3e8882c948d53abd);
#
#
#             var feature_group_9207011662c11383254ea8671453540b = L.featureGroup(
#                 {}
#             );
#
#
#             var marker_0766644cd680b64bb283398e64f9584c = L.marker(
#                 [51.277131, 12.363179],
#                 {}
#             ).addTo(feature_group_9207011662c11383254ea8671453540b);
#
#
#             var icon_a1a42a79bc9c4152e5127d52008884b0 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;play&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_0766644cd680b64bb283398e64f9584c.setIcon(icon_a1a42a79bc9c4152e5127d52008884b0);
#
#
#         var popup_7e0d02b0facfb169d957e22bfac40810 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_004b86696cdc67abc142d10b4a35f9c1 = $(`&lt;div id=&quot;html_004b86696cdc67abc142d10b4a35f9c1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Markkleeberg West (2023-12-24 05:55:00)&lt;/div&gt;`)[0];
#                 popup_7e0d02b0facfb169d957e22bfac40810.setContent(html_004b86696cdc67abc142d10b4a35f9c1);
#
#
#
#         marker_0766644cd680b64bb283398e64f9584c.bindPopup(popup_7e0d02b0facfb169d957e22bfac40810)
#         ;
#
#
#
#
#             var marker_860e206bc03d8bdcf44834434284d705 = L.marker(
#                 [51.278003, 12.368708],
#                 {}
#             ).addTo(feature_group_9207011662c11383254ea8671453540b);
#
#
#             var icon_8d1659656965ab520dcae89977e13a2f = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;circle&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_860e206bc03d8bdcf44834434284d705.setIcon(icon_8d1659656965ab520dcae89977e13a2f);
#
#
#         var popup_edddeafdce1c99700c26f52a6011560d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_915f7e64d79387fe5514a3a400cd1071 = $(`&lt;div id=&quot;html_915f7e64d79387fe5514a3a400cd1071&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Ring, Markkleeberg (2023-12-24 05:56:00)&lt;/div&gt;`)[0];
#                 popup_edddeafdce1c99700c26f52a6011560d.setContent(html_915f7e64d79387fe5514a3a400cd1071);
#
#
#
#         marker_860e206bc03d8bdcf44834434284d705.bindPopup(popup_edddeafdce1c99700c26f52a6011560d)
#         ;
#
#
#
#
#             var marker_698f1825814dd5b552e328bc80a0a106 = L.marker(
#                 [51.279244, 12.370811],
#                 {}
#             ).addTo(feature_group_9207011662c11383254ea8671453540b);
#
#
#             var icon_746c72b251888c17191cdf3b040b67e1 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;circle&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_698f1825814dd5b552e328bc80a0a106.setIcon(icon_746c72b251888c17191cdf3b040b67e1);
#
#
#         var popup_ad4f20749cda222c6d88a3078ecfcbc5 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f25169e257f47b81164ed7011cd2643f = $(`&lt;div id=&quot;html_f25169e257f47b81164ed7011cd2643f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;S-Bahnhof (Bus), Markkleeberg (2023-12-24 05:57:00)&lt;/div&gt;`)[0];
#                 popup_ad4f20749cda222c6d88a3078ecfcbc5.setContent(html_f25169e257f47b81164ed7011cd2643f);
#
#
#
#         marker_698f1825814dd5b552e328bc80a0a106.bindPopup(popup_ad4f20749cda222c6d88a3078ecfcbc5)
#         ;
#
#
#
#
#             var marker_ea17f6a2d566ef3c765e8426e884daa1 = L.marker(
#                 [51.282956, 12.370101],
#                 {}
#             ).addTo(feature_group_9207011662c11383254ea8671453540b);

# %%
# Display distinct line names
line_names = final_df.select("line_name").distinct().orderBy("line_name").collect()
line_name_options = [line["line_name"] for line in line_names]
print("Available Line Names:")
for line_name in line_name_options:
    print(line_name)
# Out:
# Available Line Names:
# Bus 60
# Bus 65
# Bus 70
# Bus 72
# Bus 73
# Bus 74
# Bus 75
# Bus 76
# Bus 80
# Bus 81
# Bus 82
# Bus 89
# Bus 90
# Bus N2
# Bus N3
# Bus N4
# Bus N5
# Bus N6
# Bus N60
# Bus N7
# Bus N8
# Bus N9
# Bus S3
# Bus S4
# Bus S5
# Bus SEV1
# S 1
# S 2
# S 3
# S 4
# S 5
# S 5X
# S 6
# STR 1
# STR 10
# STR 11
# STR 12
# STR 14
# STR 15
# STR 16
# STR 2
# STR 3
# STR 34
# STR 4
# STR 50
# STR 51
# STR 56
# STR 7
# STR 8
# STR 9
# STR N10
# STR N17

# %%
line_name = "STR 1"

def update_output(line_name):
    start_time = time.time()
    
    # Filter the dataframe for the selected line name and cache it
    line_stops = final_df.filter(col("line_name") == line_name) \
                         .select("stopId", "stop_name", "stop_latitude", "stop_longitude", "plannedWhen", "when", "delay", "added_delay", "line_name", "line_product", "direction", "tripId") \
                         .orderBy("plannedWhen") \
                         .cache()
    print(f"Filtered and cached line stops in {time.time() - start_time:.2f} seconds")
    
    # Calculate average delays for distinct stopId
    avg_delays = line_stops.groupBy("stopId", "stop_name").agg(
        avg("delay").alias("avg_delay"),
        avg("added_delay").alias("avg_added_delay")
    ).orderBy("stopId").collect()
    
    # Print the average delays with stop names
    print("Average Delays for Stops:")
    for row in avg_delays:
        print(f"Stop ID: {row['stopId']}, Stop Name: {row['stop_name']}, Avg Delay: {row['avg_delay']:.2f} seconds, Avg Added Delay: {row['avg_added_delay']:.2f} seconds")
    
    # Get the first tripId
    first_trip_id = line_stops.select("tripId").distinct().orderBy("tripId").limit(1).collect()[0]["tripId"]
    
    # Filter the stops for the first tripId
    trip_stops = line_stops.filter(col("tripId") == first_trip_id).collect()
    print(f"Collected {len(trip_stops)} stop data for the first trip in {time.time() - start_time:.2f} seconds")

    if trip_stops:
        avg_latitude = sum([float(stop["stop_latitude"]) for stop in trip_stops]) / len(trip_stops)
        avg_longitude = sum([float(stop["stop_longitude"]) for stop in trip_stops]) / len(trip_stops)
        m = folium.Map(location=[avg_latitude, avg_longitude], zoom_start=13)

        # Create a feature group for the stops
        stops_group = folium.FeatureGroup(name='Stops')

        # Function to map delay to a color for stops
        def stop_delay_to_color(delay):
            if delay < 60:
                return 'blue'
            elif delay <= 120:
                return 'green'
            elif delay <= 180:
                return 'lightred'
            elif delay <= 240:
                return 'orange'
            else:
                return 'red'

        # Create a dictionary to map stopId to avg_added_delay
        avg_delays_dict = {row['stopId']: row['avg_delay'] for row in avg_delays}
        avg_added_delay_dict = {row['stopId']: row['avg_added_delay'] for row in avg_delays}

        # Add a marker for each stop with different icons for start, end, and intermediate stops
        for i, stop in enumerate(trip_stops):
            stop_color = stop_delay_to_color(float(stop["delay"]))
            avg_delay = avg_delays_dict.get(stop["stopId"], 0)
            avg_added_delay = avg_added_delay_dict.get(stop["stopId"], 0)
            popup_text = f"{stop['stop_name']} (Avg Delay: {avg_delay:.2f} seconds, Avg Added Delay: {avg_added_delay:.2f} seconds)"
            if i == 0:
                # Start stop
                folium.Marker(
                    location=[float(stop["stop_latitude"]), float(stop["stop_longitude"])],
                    popup=popup_text,
                    icon=folium.Icon(color=stop_color, icon='play', prefix='fa')
                ).add_to(stops_group)
            elif i == len(trip_stops) - 1:
                # End stop
                folium.Marker(
                    location=[float(stop["stop_latitude"]), float(stop["stop_longitude"])],
                    popup=popup_text,
                    icon=folium.Icon(color=stop_color, icon='stop', prefix='fa')
                ).add_to(stops_group)
            else:
                # Intermediate stops
                folium.Marker(
                    location=[float(stop["stop_latitude"]), float(stop["stop_longitude"])],
                    popup=popup_text,
                    icon=folium.Icon(color=stop_color, icon='circle', prefix='fa')
                ).add_to(stops_group)

        # Add the stops group to the map
        stops_group.add_to(m)

        # Create a list of coordinates for the stops
        coords = [[float(stop["stop_latitude"]), float(stop["stop_longitude"])] for stop in trip_stops]
        colors = [avg_added_delay_dict.get(stop["stopId"], 0) for stop in trip_stops[1:]]  # Colors based on average added delay for each segment

        # Calculate min and max added delay for normalization
        min_delay = min(colors)
        max_delay = max(colors)

        # Normalize colors to be between 0 and 1 for colormap
        colors = [(delay - min_delay) / (max_delay - min_delay) if max_delay > min_delay else 0 for delay in colors]

        # Add a ColorLine to the map
        folium.ColorLine(
            positions=coords,
            colors=colors,
            colormap=["green", "yellow", "orange", "red"],
            weight=5
        ).add_to(m)

        # Display the map
        display(m)
        print(f"Displayed map in {time.time() - start_time:.2f} seconds")
    else:
        print("No stops found for the selected line name.")

# Call the function with the hardcoded line name
update_output(line_name)
# Out:
# Filtered and cached line stops in 1.80 seconds
# Average Delays for Stops:
# Stop ID: 953844, Stop Name: Gottschedstr., Leipzig, Avg Delay: 26.98 seconds, Avg Added Delay: 1.40 seconds
# Stop ID: 953848, Stop Name: Gerichtsweg, Leipzig, Avg Delay: 35.35 seconds, Avg Added Delay: 1.63 seconds
# Stop ID: 953904, Stop Name: Lausen, Leipzig, Avg Delay: 25.58 seconds, Avg Added Delay: 0.00 seconds
# Stop ID: 953905, Stop Name: Heisenbergstr., Leipzig, Avg Delay: 40.36 seconds, Avg Added Delay: -1.09 seconds
# Stop ID: 954584, Stop Name: Klingerweg, Leipzig, Avg Delay: 35.58 seconds, Avg Added Delay: 0.23 seconds
# Stop ID: 954609, Stop Name: Westplatz, Leipzig, Avg Delay: 28.14 seconds, Avg Added Delay: 0.93 seconds
# Stop ID: 954667, Stop Name: Ahornstr., Leipzig, Avg Delay: 44.65 seconds, Avg Added Delay: 4.65 seconds
# Stop ID: 955103, Stop Name: Wiebelstr., Leipzig, Avg Delay: 41.16 seconds, Avg Added Delay: 5.12 seconds
# Stop ID: 955244, Stop Name: Paunsdorf Theodor-Heuss-Str., Leipzig, Avg Delay: 49.53 seconds, Avg Added Delay: 0.00 seconds
# Stop ID: 955251, Stop Name: Augustusplatz, Leipzig, Avg Delay: 31.63 seconds, Avg Added Delay: 2.09 seconds
# Stop ID: 955310, Stop Name: Stuttgarter Allee, Leipzig, Avg Delay: 47.91 seconds, Avg Added Delay: -4.42 seconds
# Stop ID: 955501, Stop Name: Johannisplatz, Leipzig, Avg Delay: 31.86 seconds, Avg Added Delay: -0.23 seconds
# Stop ID: 955514, Stop Name: Rödelstr., Leipzig, Avg Delay: 40.00 seconds, Avg Added Delay: 2.56 seconds
# Stop ID: 955515, Stop Name: Marschnerstr., Leipzig, Avg Delay: 31.86 seconds, Avg Added Delay: 2.09 seconds
# Stop ID: 956020, Stop Name: Holbeinstr., Leipzig, Avg Delay: 37.91 seconds, Avg Added Delay: 0.70 seconds
# Stop ID: 956037, Stop Name: Paunsdorf Straßenbahnhof, Leipzig, Avg Delay: 58.14 seconds, Avg Added Delay: 1.86 seconds
# Stop ID: 956053, Stop Name: Zschampertaue, Leipzig, Avg Delay: 44.42 seconds, Avg Added Delay: 2.33 seconds
# Stop ID: 956058, Stop Name: Sellerhausen Emmausstr., Leipzig, Avg Delay: 44.42 seconds, Avg Added Delay: 0.00 seconds
# Stop ID: 956059, Stop Name: Geißlerstr./Bülowviertel, Leipzig, Avg Delay: 42.33 seconds, Avg Added Delay: -0.23 seconds
# Stop ID: 956291, Stop Name: Hauptbahnhof (Tram/Bus), Leipzig, Avg Delay: 16.05 seconds, Avg Added Delay: -25.58 seconds
# Stop ID: 956415, Stop Name: Stieglitzstr., Leipzig, Avg Delay: 37.44 seconds, Avg Added Delay: 0.23 seconds
# Stop ID: 956502, Stop Name: Reudnitz Koehlerstr., Leipzig, Avg Delay: 40.47 seconds, Avg Added Delay: 6.28 seconds
# Stop ID: 956518, Stop Name: Schönauer/Ratzelstr., Leipzig, Avg Delay: 54.19 seconds, Avg Added Delay: 1.40 seconds
# Stop ID: 956536, Stop Name: Ratzelbogen, Leipzig, Avg Delay: 46.74 seconds, Avg Added Delay: 0.47 seconds
# Stop ID: 956612, Stop Name: Ostheimstr., Leipzig, Avg Delay: 47.44 seconds, Avg Added Delay: 2.33 seconds
# Stop ID: 956638, Stop Name: Torgauer Platz, Leipzig, Avg Delay: 43.02 seconds, Avg Added Delay: 5.58 seconds
# Stop ID: 956897, Stop Name: Diezmannstr., Leipzig, Avg Delay: 57.91 seconds, Avg Added Delay: 4.88 seconds
# Stop ID: 956945, Stop Name: Am Vorwerk, Leipzig, Avg Delay: 56.51 seconds, Avg Added Delay: 8.60 seconds
# Stop ID: 957394, Stop Name: Adler, Leipzig, Avg Delay: 49.77 seconds, Avg Added Delay: 8.60 seconds
# Stop ID: 957401, Stop Name: Annenstr., Leipzig, Avg Delay: 44.19 seconds, Avg Added Delay: 0.93 seconds
# Stop ID: 957423, Stop Name: Krakauer Str., Leipzig, Avg Delay: 43.95 seconds, Avg Added Delay: -1.16 seconds
# Stop ID: 957450, Stop Name: Barbarastr., Leipzig, Avg Delay: 55.58 seconds, Avg Added Delay: 4.65 seconds
# Stop ID: 957647, Stop Name: Kurt-Kresse-Str., Leipzig, Avg Delay: 57.44 seconds, Avg Added Delay: 0.93 seconds
# Stop ID: 957762, Stop Name: Paunsdorf Nord, Leipzig, Avg Delay: 18.86 seconds, Avg Added Delay: -6.86 seconds
# Stop ID: 957859, Stop Name: Goerdelerring, Leipzig, Avg Delay: 29.07 seconds, Avg Added Delay: 4.42 seconds
# Stop ID: 958070, Stop Name: Herrmann-Meyer-Str., Leipzig, Avg Delay: 54.19 seconds, Avg Added Delay: -2.79 seconds
# Stop ID: 958131, Stop Name: Portitzer Allee/S-Bahnhof Heiterblick, Leipzig, Avg Delay: 20.00 seconds, Avg Added Delay: 0.00 seconds
# Stop ID: 958350, Stop Name: Antonien-/Gießerstr., Leipzig, Avg Delay: 55.81 seconds, Avg Added Delay: 6.98 seconds
# Collected 35 stop data for the first trip in 61.93 seconds
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c9cde2e16c5ba50ca56342c47221ac77 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c9cde2e16c5ba50ca56342c47221ac77&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c9cde2e16c5ba50ca56342c47221ac77 = L.map(
#                 &quot;map_c9cde2e16c5ba50ca56342c47221ac77&quot;,
#                 {
#                     center: [51.333676685714295, 12.373514257142856],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2545d539eb952e40d6ac9ddbea1a46ea = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_2545d539eb952e40d6ac9ddbea1a46ea.addTo(map_c9cde2e16c5ba50ca56342c47221ac77);
#
#
#             var feature_group_5d02d7d4f34ae2c3c6e2da30afa4a4c2 = L.featureGroup(
#                 {}
#             );
#
#
#             var marker_204ec3939f72ce726bdbcc319bc8dd72 = L.marker(
#                 [51.360884, 12.470591],
#                 {}
#             ).addTo(feature_group_5d02d7d4f34ae2c3c6e2da30afa4a4c2);
#
#
#             var icon_73a11884761c8fe57925393fa7221247 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;play&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_204ec3939f72ce726bdbcc319bc8dd72.setIcon(icon_73a11884761c8fe57925393fa7221247);
#
#
#         var popup_dfd7f6a0630907583b68ce0563181014 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ac2118708275df157916aeccb8cd321c = $(`&lt;div id=&quot;html_ac2118708275df157916aeccb8cd321c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Paunsdorf Nord, Leipzig (Avg Delay: 18.86 seconds, Avg Added Delay: -6.86 seconds)&lt;/div&gt;`)[0];
#                 popup_dfd7f6a0630907583b68ce0563181014.setContent(html_ac2118708275df157916aeccb8cd321c);
#
#
#
#         marker_204ec3939f72ce726bdbcc319bc8dd72.bindPopup(popup_dfd7f6a0630907583b68ce0563181014)
#         ;
#
#
#
#
#             var marker_fcf2cfd558abc61f20c62947fcecf9b0 = L.marker(
#                 [51.356156, 12.460218],
#                 {}
#             ).addTo(feature_group_5d02d7d4f34ae2c3c6e2da30afa4a4c2);
#
#
#             var icon_2251706ac7a29c73d918f0a2512809ac = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;circle&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_fcf2cfd558abc61f20c62947fcecf9b0.setIcon(icon_2251706ac7a29c73d918f0a2512809ac);
#
#
#         var popup_27f1deb2a745a66e6c23cfa8a713e403 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_70ee36f05262ad6920c1c85e1420ae3e = $(`&lt;div id=&quot;html_70ee36f05262ad6920c1c85e1420ae3e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Ahornstr., Leipzig (Avg Delay: 44.65 seconds, Avg Added Delay: 4.65 seconds)&lt;/div&gt;`)[0];
#                 popup_27f1deb2a745a66e6c23cfa8a713e403.setContent(html_70ee36f05262ad6920c1c85e1420ae3e);
#
#
#
#         marker_fcf2cfd558abc61f20c62947fcecf9b0.bindPopup(popup_27f1deb2a745a66e6c23cfa8a713e403)
#         ;
#
#
#
#
#             var marker_33934bcdd111697149255a0731b026bf = L.marker(
#                 [51.352317, 12.458941],
#                 {}
#             ).addTo(feature_group_5d02d7d4f34ae2c3c6e2da30afa4a4c2);
#
#
#             var icon_dc2399a02b8f39435236f145526397fe = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;circle&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_33934bcdd111697149255a0731b026bf.setIcon(icon_dc2399a02b8f39435236f145526397fe);
#
#
#         var popup_cd4c9f9da6725dd33458cb1c685ab079 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_fd1c32d6ad9a46ab2172bbf82144c4b2 = $(`&lt;div id=&quot;html_fd1c32d6ad9a46ab2172bbf82144c4b2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Am Vorwerk, Leipzig (Avg Delay: 56.51 seconds, Avg Added Delay: 8.60 seconds)&lt;/div&gt;`)[0];
#                 popup_cd4c9f9da6725dd33458cb1c685ab079.setContent(html_fd1c32d6ad9a46ab2172bbf82144c4b2);
#
#
#
#         marker_33934bcdd111697149255a0731b026bf.bindPopup(popup_cd4c9f9da6725dd33458cb1c685ab079)
#         ;
#
#
#
#
#             var marker_64374989a2df2c73825ea5502abefc61 = L.marker(
#                 [51.345
# Displayed map in 62.25 seconds
